# %% [markdown]
# ## 제공된 데이터를 이용하여 학습하는 소스코드를 작성 (1시간 이내 종료)
# -	Github 개인 repository를 private로 생성
# -	Collaborator로 팀을 이룬 상대방 계정과, 조교 계정(Artinto) 추가
#   **만든 repository이동 -> settings -> Collaborator -> 아이디 검색해 추가**
# -	데이터셋을 개인 ‘드라이브’에 업로드하고 Colab에 연결

# %% [markdown]
# # Colab에서 소스코드 작성 및 학습

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/AIAppl
# Out:
# /content/drive/MyDrive/AIAppl

# %%
# !git clone "https://github.com/challengingJC/AIstudy.git"
# Out:
# Cloning into 'AIstudy'...
# remote: Enumerating objects: 15, done.
# remote: Counting objects: 100% (15/15), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 15 (delta 5), reused 0 (delta 0), pack-reused 0
# Unpacking objects: 100% (15/15), done.

# %%
pwd
# Out:
# '/content/drive/MyDrive/AIAppl/AIstudy'

# %%
cd ./AIstudy/
# Out:
# /content/drive/MyDrive/AIAppl/AIstudy

# %%
# !git init

# %%
# !git add .
# !git commit -m "Edit Midterm.ipynb"
# Out:
# *** Please tell me who you are.
#
# Run
#
#   git config --global user.email "you@example.com"
#   git config --global user.name "Your Name"
#
# to set your account's default identity.
# Omit --global to set the identity only in this repository.
#
# fatal: unable to auto-detect email address (got 'root@238661a20127.(none)')

# %% [markdown]
# # Repository로 Push하기

# %%
# !git remote add repo-basic2 https://challengingJC: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@github.com/challengingJC/AIstudy.git
# !git push -u repo-basic2 main
# Out:
# Branch 'main' set up to track remote branch 'main' from 'repo-basic2'.
# Everything up-to-date
